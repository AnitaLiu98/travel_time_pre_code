# %%
# -*- coding: utf-8 -*-
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

# %%
#Load data
df1=pd.read_csv('./processed_data/train_1.csv',encoding='utf-8')
#df2=pd.read_csv('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/weekday_data_train_withday.csv',encoding='utf-8')
df3=pd.read_excel('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/2h_route_avg_train.xlsx',encoding='utf-8')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'intersection_id', 'tollgate_id', 'time_window',
#        'avg_travel_time', 'route', 'avg_travel_time_log', 'start_datetime',
#        'start_hour', 'day_of_week', 'weekday', 'holiday', 'rush_hour',
#        'hour_of_day', 'date', 'hour', 'pressure', 'sea_pressure',
#        'wind_direction', 'wind_speed', 'temperature', 'rel_humidity',
#        'precipitation', 'datetime'],
#       dtype='object')

# %%
df1.shape
# Out:
# (25144, 24)

# %%
df1['route']=df1['intersection_id']+'-'+df1['tollgate_id'].astype('str')
df3['route']=df3['intersection_id']+'-'+df3['tollgate_id'].astype('str')

# %%
df3.head(2)
# Out:
#   intersection_id  tollgate_id                                time_window  \
# 0               B            3  [2016-07-19 00:00:00,2016-07-19 00:20:00)
# 1               B            3  [2016-07-19 00:20:00,2016-07-19 00:40:00)
#
#    avg_travel_time   time_window_start     time_window_end  \
# 0            70.85 2016-07-19 00:00:00 2016-07-19 00:20:00
# 1           148.79 2016-07-19 00:20:00 2016-07-19 00:40:00
#
#   time_window_2h_start             link_seq  \
# 0  2016-07-18 22:00:00  105,100,111,103,122
# 1  2016-07-18 22:20:00  105,100,111,103,122
#
#                              link_list  link_num  road_length  \
# 0  ['105', '100', '111', '103', '122']         5          477
# 1  ['105', '100', '111', '103', '122']         5          477
#
#    route_car_number  route_avg_speed  route_avg_traveltime  \
# 0                 0              inf                   0.0
# 1                 1         6.814286                  70.0
#
#    route_total_traveltime route
# ...

# %%
df1.shape
# Out:
# (25144, 24)

# %%
df3.columns
# Out:
# Index(['intersection_id', 'tollgate_id', 'time_window', 'avg_travel_time',
#        'time_window_start', 'time_window_end', 'time_window_2h_start',
#        'link_seq', 'link_list', 'link_num', 'road_length', 'route_car_number',
#        'route_avg_speed', 'route_avg_traveltime', 'route_total_traveltime',
#        'route'],
#       dtype='object')

# %%
df1.columns
# Out:
# Index(['Unnamed: 0', 'intersection_id', 'tollgate_id', 'time_window',
#        'avg_travel_time', 'route', 'avg_travel_time_log', 'start_datetime',
#        'start_hour', 'day_of_week', 'weekday', 'holiday', 'rush_hour',
#        'hour_of_day', 'date', 'hour', 'pressure', 'sea_pressure',
#        'wind_direction', 'wind_speed', 'temperature', 'rel_humidity',
#        'precipitation', 'datetime'],
#       dtype='object')

# %%
# df3 = pd.merge(df2[['route','time_window']],df3,how='left',on=['route','time_window'])

# %%
df3.shape
# Out:
# (25144, 16)

# %%
dfnn=df3[['route', 'time_window_2h_start', 'route_car_number',
       'route_avg_speed', 'route_avg_traveltime', 'route_total_traveltime']]

# %%
df1.shape
# Out:
# (25144, 24)

# %%
dfnn.columns
# Out:
# Index(['route', 'time_window_2h_start', 'route_car_number', 'route_avg_speed',
#        'route_avg_traveltime', 'route_total_traveltime'],
#       dtype='object')

# %%
from datetime import datetime
from datetime import timedelta
min_delta=pd.to_datetime('2019-9-4 00:20:00') - pd.to_datetime('2019-9-4 00:00:00')
min_delta
h2_delta=pd.to_datetime('2019-9-4 02:00:00') - pd.to_datetime('2019-9-4 00:00:00')
h2_delta
# Out:
# Timedelta('0 days 02:00:00')

# %% [raw]
# dfnn['time_window_2h_start']=pd.to_datetime(dfnn['time_window_2h_start'])

# %%
dfnn['time_after_start1']=dfnn['time_window_2h_start']+h2_delta
dfnn['time_after_start2']=dfnn['time_window_2h_start']+h2_delta+min_delta
dfnn['time_after_start3']=dfnn['time_window_2h_start']+h2_delta+2*min_delta
dfnn['time_after_start4']=dfnn['time_window_2h_start']+h2_delta+3*min_delta
dfnn['time_after_start5']=dfnn['time_window_2h_start']+h2_delta+4*min_delta
dfnn['time_after_start6']=dfnn['time_window_2h_start']+h2_delta+5*min_delta
# Out:
# /Users/liuxueling/anaconda2/envs/python35/lib/python3.5/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/liuxueling/anaconda2/envs/python35/lib/python3.5/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/liuxueling/anaconda2/envs/python35/lib/python3.5/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfnn.shape
# Out:
# (25144, 12)

# %%
time_window_new=df1['time_window'].str.lstrip('[')
time_window_new=time_window_new.str.rstrip(')')
time_window_new=time_window_new.str.split(',',expand=True)
time_window_new
df1['time_window_start']=pd.to_datetime(time_window_new[0])
df1['time_window_end']=pd.to_datetime(time_window_new[1])
df1.head(5)
# Out:
#    Unnamed: 0 intersection_id  tollgate_id  \
# 0           0               B            3
# 1           1               A            2
# 2           2               B            1
# 3           3               B            3
# 4           4               B            1
#
#                                  time_window  avg_travel_time route  \
# 0  [2016-07-19 00:00:00,2016-07-19 00:20:00)            70.85   B-3
# 1  [2016-07-19 00:20:00,2016-07-19 00:40:00)            58.05   A-2
# 2  [2016-07-19 00:20:00,2016-07-19 00:40:00)            79.76   B-1
# 3  [2016-07-19 00:20:00,2016-07-19 00:40:00)           148.79   B-3
# 4  [2016-07-19 00:40:00,2016-07-19 01:00:00)           137.98   B-1
#
#    avg_travel_time_log       start_datetime  start_hour  day_of_week  \
# 0             4.274581  2016-07-19 00:00:00           0            1
# 1             4.078385  2016-07-19 00:20:00           0            1
# 2             4.391482  2016-07-19 00:20:00           0            1
# ...

# %%
df1['start_datetime']=pd.to_datetime(df['start_datetime'])

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start1'],right_on=['route','time_window_start'],suffixes=('_nn', '_1'))#.rename(columns={'avg_travel_time':'avg_travel_time1'}) #df3['time_window_2h_start']

# %%
dfnn.shape
# Out:
# (25144, 37)

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start2'],right_on=['route','time_window_start'],suffixes=('_1', '_2'))#.rename(columns={'avg_travel_time':'avg_travel_time1'}) #df3['time_window_2h_start']

# %%
dfnn.shape
# Out:
# (20395, 62)

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start3'],right_on=['route','time_window_start'],suffixes=('_2', '_3'))#.rename(columns={'avg_travel_time':'avg_travel_time1'}) #df3['time_window_2h_start']

# %%
dfnn.columns
# Out:
# Index(['route', 'time_window_2h_start', 'route_car_number', 'route_avg_speed',
#        'route_avg_traveltime', 'route_total_traveltime', 'time_after_start1',
#        'time_after_start2', 'time_after_start3', 'time_after_start4',
#        'time_after_start5', 'time_after_start6', 'Unnamed: 0_1',
#        'intersection_id_1', 'tollgate_id_1', 'time_window_1',
#        'avg_travel_time_1', 'avg_travel_time_log_1', 'start_datetime_1',
#        'start_hour_1', 'day_of_week_1', 'weekday_1', 'holiday_1',
#        'rush_hour_1', 'hour_of_day_1', 'date_1', 'hour_1', 'pressure_1',
#        'sea_pressure_1', 'wind_direction_1', 'wind_speed_1', 'temperature_1',
#        'rel_humidity_1', 'precipitation_1', 'datetime_1',
#        'time_window_start_1', 'time_window_end_1', 'Unnamed: 0_2',
#        'intersection_id_2', 'tollgate_id_2', 'time_window_2',
#        'avg_travel_time_2', 'avg_travel_time_log_2', 'start_datetime_2',
#        'start_hour_2', 'day_of_week_2', 'weekday_2', 'holiday_2',
# ...

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start4'],right_on=['route','time_window_start'],suffixes=('_3', '_4')) #df3['time_window_2h_start']

dfnn.head(5)
# Out:
#   route time_window_2h_start  route_car_number  route_avg_speed  \
# 0   B-3  2016-07-19 01:40:00                 5         4.042373
# 1   B-3  2016-07-19 02:00:00                 7         4.194724
# 2   B-3  2016-07-19 04:00:00                 6         5.056537
# 3   B-3  2016-07-19 04:20:00                 5         4.595376
# 4   B-3  2016-07-19 04:40:00                 5         4.021922
#
#    route_avg_traveltime  route_total_traveltime   time_after_start1  \
# 0            118.000000                     590 2016-07-19 03:40:00
# 1            113.714286                     796 2016-07-19 04:00:00
# 2             94.333333                     566 2016-07-19 06:00:00
# 3            103.800000                     519 2016-07-19 06:20:00
# 4            118.600000                     593 2016-07-19 06:40:00
#
#     time_after_start2   time_after_start3   time_after_start4  \
# 0 2016-07-19 04:00:00 2016-07-19 04:20:00 2016-07-19 04:40:00
# ...

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start5'],right_on=['route','time_window_start'],suffixes=('_4', '_5')) #df3['time_window_2h_start']

dfnn.head(5)
# Out:
#   route time_window_2h_start  route_car_number  route_avg_speed  \
# 0   B-3  2016-07-19 01:40:00                 5         4.042373
# 1   B-3  2016-07-19 04:00:00                 6         5.056537
# 2   B-3  2016-07-19 04:20:00                 5         4.595376
# 3   B-3  2016-07-19 04:40:00                 5         4.021922
# 4   B-3  2016-07-19 05:00:00                 4         3.289655
#
#    route_avg_traveltime  route_total_traveltime   time_after_start1  \
# 0            118.000000                     590 2016-07-19 03:40:00
# 1             94.333333                     566 2016-07-19 06:00:00
# 2            103.800000                     519 2016-07-19 06:20:00
# 3            118.600000                     593 2016-07-19 06:40:00
# 4            145.000000                     580 2016-07-19 07:00:00
#
#     time_after_start2   time_after_start3   time_after_start4  \
# 0 2016-07-19 04:00:00 2016-07-19 04:20:00 2016-07-19 04:40:00
# ...

# %%
dfnn = pd.merge(dfnn,df1,how='inner',left_on=['route','time_after_start6'],right_on=['route','time_window_start'],suffixes=('_5', '_6')) #df3['time_window_2h_start']

dfnn.head(5)
# Out:
#   route time_window_2h_start  route_car_number  route_avg_speed  \
# 0   B-3  2016-07-19 04:00:00                 6         5.056537
# 1   B-3  2016-07-19 04:20:00                 5         4.595376
# 2   B-3  2016-07-19 04:40:00                 5         4.021922
# 3   B-3  2016-07-19 05:00:00                 4         3.289655
# 4   B-3  2016-07-19 05:20:00                 8         3.966736
#
#    route_avg_traveltime  route_total_traveltime   time_after_start1  \
# 0             94.333333                     566 2016-07-19 06:00:00
# 1            103.800000                     519 2016-07-19 06:20:00
# 2            118.600000                     593 2016-07-19 06:40:00
# 3            145.000000                     580 2016-07-19 07:00:00
# 4            120.250000                     962 2016-07-19 07:20:00
#
#     time_after_start2   time_after_start3   time_after_start4  \
# 0 2016-07-19 06:20:00 2016-07-19 06:40:00 2016-07-19 07:00:00
# ...

# %%
dfnn.shape
# Out:
# (14083, 162)

# %%
print(list(dfnn.columns))
# Out:
# ['route', 'time_window_2h_start', 'route_car_number', 'route_avg_speed', 'route_avg_traveltime', 'route_total_traveltime', 'time_after_start1', 'time_after_start2', 'time_after_start3', 'time_after_start4', 'time_after_start5', 'time_after_start6', 'Unnamed: 0_1', 'intersection_id_1', 'tollgate_id_1', 'time_window_1', 'avg_travel_time_1', 'avg_travel_time_log_1', 'start_datetime_1', 'start_hour_1', 'day_of_week_1', 'weekday_1', 'holiday_1', 'rush_hour_1', 'hour_of_day_1', 'date_1', 'hour_1', 'pressure_1', 'sea_pressure_1', 'wind_direction_1', 'wind_speed_1', 'temperature_1', 'rel_humidity_1', 'precipitation_1', 'datetime_1', 'time_window_start_1', 'time_window_end_1', 'Unnamed: 0_2', 'intersection_id_2', 'tollgate_id_2', 'time_window_2', 'avg_travel_time_2', 'avg_travel_time_log_2', 'start_datetime_2', 'start_hour_2', 'day_of_week_2', 'weekday_2', 'holiday_2', 'rush_hour_2', 'hour_of_day_2', 'date_2', 'hour_2', 'pressure_2', 'sea_pressure_2', 'wind_direction_2', 'wind_speed_2', 'temp
# ...

# %%
dfnn.to_csv('./processed_data/training_nn.csv')

# %% [markdown]
# # test数据，待修改

# %%
#Load data
df4=pd.read_csv('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/test_1.csv',encoding='utf-8')
df5=pd.read_csv('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/test_data_with_weekdata 1.csv',encoding='utf-8')
df6=pd.read_excel('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/2h_route_avg_test.xlsx',encoding='utf-8')

# %%
df4['route']=df4['intersection_id']+'-'+df4['tollgate_id'].astype('str')
df6['route']=df6['intersection_id']+'-'+df6['tollgate_id'].astype('str')

# %%
df5['time_window']=df5['time_window'].astype('str')
df4['time_window']=df4['time_window'].astype('str')

# %%
set(df5['time_window'].values)
# Out:
# {'[2016-10-18 08:00:00,2016-10-18 08:20:00)',
#  '[2016-10-18 08:20:00,2016-10-18 08:40:00)',
#  '[2016-10-18 08:40:00,2016-10-18 09:00:00)',
#  '[2016-10-18 09:00:00,2016-10-18 09:20:00)',
#  '[2016-10-18 09:20:00,2016-10-18 09:40:00)',
#  '[2016-10-18 09:40:00,2016-10-18 10:00:00)',
#  '[2016-10-18 17:00:00,2016-10-18 17:20:00)',
#  '[2016-10-18 17:20:00,2016-10-18 17:40:00)',
#  '[2016-10-18 17:40:00,2016-10-18 18:00:00)',
#  '[2016-10-18 18:00:00,2016-10-18 18:20:00)',
#  '[2016-10-18 18:20:00,2016-10-18 18:40:00)',
#  '[2016-10-18 18:40:00,2016-10-18 19:00:00)',
#  '[2016-10-19 08:00:00,2016-10-19 08:20:00)',
#  '[2016-10-19 08:20:00,2016-10-19 08:40:00)',
#  '[2016-10-19 08:40:00,2016-10-19 09:00:00)',
#  '[2016-10-19 09:00:00,2016-10-19 09:20:00)',
#  '[2016-10-19 09:20:00,2016-10-19 09:40:00)',
#  '[2016-10-19 09:40:00,2016-10-19 10:00:00)',
#  '[2016-10-19 17:00:00,2016-10-19 17:20:00)',
#  '[2016-10-19 17:20:00,2016-10-19 17:40:00)',
# ...

# %%
set(df4['time_window'].values)
# Out:
# {'[2016-10-18 08:00:00,2016-10-18 08:20:00)',
#  '[2016-10-18 08:20:00,2016-10-18 08:40:00)',
#  '[2016-10-18 08:40:00,2016-10-18 09:00:00)',
#  '[2016-10-18 09:00:00,2016-10-18 09:20:00)',
#  '[2016-10-18 09:20:00,2016-10-18 09:40:00)',
#  '[2016-10-18 09:40:00,2016-10-18 10:00:00)',
#  '[2016-10-18 17:00:00,2016-10-18 17:20:00)',
#  '[2016-10-18 17:20:00,2016-10-18 17:40:00)',
#  '[2016-10-18 17:40:00,2016-10-18 18:00:00)',
#  '[2016-10-18 18:00:00,2016-10-18 18:20:00)',
#  '[2016-10-18 18:20:00,2016-10-18 18:40:00)',
#  '[2016-10-18 18:40:00,2016-10-18 19:00:00)',
#  '[2016-10-19 08:00:00,2016-10-19 08:20:00)',
#  '[2016-10-19 08:20:00,2016-10-19 08:40:00)',
#  '[2016-10-19 08:40:00,2016-10-19 09:00:00)',
#  '[2016-10-19 09:00:00,2016-10-19 09:20:00)',
#  '[2016-10-19 09:20:00,2016-10-19 09:40:00)',
#  '[2016-10-19 09:40:00,2016-10-19 10:00:00)',
#  '[2016-10-19 17:00:00,2016-10-19 17:20:00)',
#  '[2016-10-19 17:20:00,2016-10-19 17:40:00)',
# ...

# %%
df5.dtypes
# Out:
# avg_travel_time                   float64
# intersection_id                    object
# time_window                        object
# time_window_index                   int64
# tollgate_id                         int64
# weekday                             int64
# route                              object
# link_seq                           object
# week_time_avg_speed               float64
# week_route_car_number               int64
# week_time_avg_travel_time         float64
# route_avg_link_avg_travel_time    float64
# route_avg_link_avg_speed          float64
# dtype: object

# %%
df=pd.merge(df5,df4,how='left',on=['route','time_window'])

# %%
df.head(2)
# Out:
#    avg_travel_time_x intersection_id_x  \
# 0             681.30                 A
# 1             128.11                 A
#
#                                  time_window  time_window_index  \
# 0  [2016-10-18 08:00:00,2016-10-18 08:20:00)                  0
# 1  [2016-10-18 08:20:00,2016-10-18 08:40:00)                  1
#
#    tollgate_id_x  weekday_x route                 link_seq  \
# 0              2          1   A-2  110,123,107,108,120,117
# 1              2          1   A-2  110,123,107,108,120,117
#
#    week_time_avg_speed  week_route_car_number         ...           \
# 0             5.868187                    129         ...
# 1             6.025384                    140         ...
#
#          date  hour  pressure  sea_pressure wind_direction  wind_speed  \
# 0  2016-10-18     6    1012.5        1017.5          128.0         1.6
# 1  2016-10-18     6    1012.5        1017.5          128.0         1.6
#
# ...

# %%
df=pd.merge(df,df6,how='left',on=['route','time_window'])

# %%
df.shape
# Out:
# (504, 48)

# %%
df.to_csv('/Users/liuxueling/PycharmProjects/python3pj/5002/Project/data5002/processed_data/test_merge.csv')
